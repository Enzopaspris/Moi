# %%
class annee:
    from datetime import date
    AJD=date.today()
    An_actuel = AJD.year
    Mois_actuel=AJD.month
    Jour_actuel=AJD.day
    
    def __init__(self, a):
        self.a = a
        self._a = a
    
    def bisextile(self, a):
        if int(self.a)>=1582:
            if (int(self.a)%4==0 and not int(self.a)%100==0) or int(self.a)%400==0:
                return f"{self.a} est une année bisextile "
            else :
                    return f"{self.a} n'est pas une année bisextile "
        else:
            return f"Votre année est inférieur a 1582"
        
    def age(self, a, m, j):
        if (M_naissance>Mois_actuel) or (M_naissance==Mois_actuel and J_naissance>Jour_actuel):
            Age= An_actuel-A_naissance-1
            else :
                Age = An_actuel-A_naissance
                return f"Tu as{self.a}
        
    def __repr__(self):
        return str(self.a)
    
    def __str__(self):
        return str(self.a)
# Out:
#   File "<input>", line 24
#     else :
#     ^
# SyntaxError: invalid syntax

# %%
a = 1585
f = annee(a)
print(f.bisextile(a))
# Out:
# 1585 n'est pas une année bisextile
