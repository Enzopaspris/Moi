# %%
def affichage(T):
    """
    >>> affichage([1, 2, 3, 4])
    1
    2
    3
    4
    """
    if len(T) == 0 : return
    print(T[0])
    return affichage(T[1:])

def inversion_tab(T, L=[]):
    """
    >>> inversion_tab([1, 2, 3, 4])
    [4, 3, 2, 1]
    """
    if len(T) == 0 : return L
    L.append(T[-1])
    return inversion_tab(T[:-1], L)

def mediane(T):
    """
    >>> mediane([1, 2, 3, 4])
    2.5
    >>> mediane([1, 2, 3])
    2
    >>> mediane([6, 2, -4])
    2
    
    """
    if len(T) == 1 : return T[0]
    elif len(T) == 2 : return (T[0] + T[1]) / 2
    return mediane(T[1:-1])

def recherche(T, e):
    """
    >>> recherche([1,2,3,4,5], 3)
    True
    >>> recherche([1,2,3,4,5], 6)
    False
    """
    if e < T[len(T)//2] : return recherche(T[:len(T)//2],e) 
    if e > T[len(T)//2] : return recherche(T[len(T)//2:],e)
    if e == T[len(T)//2] : return True
    if 
    


if __name__ == "__main__":
    import doctest
    
    doctest.testmod()
# Out:
#   File "<input>", line 46
#     if
#       ^
# SyntaxError: invalid syntax
