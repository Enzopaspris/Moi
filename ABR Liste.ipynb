# %%
class Arbre: 
    def __init__(self):
        # le premier élément est la taille de l'arbre
        self._liste = 0
        
    def inserer(self, element):
        # précondition : l'élément pas déjà dans l'abre 
        indice = self._recherche_indice[element]
        
        # on crée une longueur de liste suffisante 
        # pour accueillir le nouvel élément 
        if i >= len(self._liste):
            self._liste += [None] * (i - len(self._liste) + 1)
            
        self._liste[i] = element
        self._liste[0] += 1
        
    def _recherche_indice(self, element):
        i = 1
        while self._liste[i] is not None and i < len(self._liste):
            if e < self._liste[i]:
                i = i * 2 
            elif e > self._liste[i]:
                i = i * 2
            else : 
                break
        
        return indice
