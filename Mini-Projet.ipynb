# %%
import datetime
AJD=date.today()
An_actuel = AJD.year
Mois_actuel=AJD.month
Jour_actuel=AJD.day

class naissance:
               
    def __init__(self, j, m, a):
        self.a = a
        self.m = m
        self.j = j
    
    def anniversaire(self, j, m, a):       
        d0 = date(self.a ,self.m, self.j)
        d1 = datetime.date.today()
        delta = abs(d1 - d0)
        if d1 == d0:
            return f"Bon anniversaire !"
        else:
            return f"Ton anniversaire est dans {delta.days} jours "

        
    def bissextile(self,j, m, a):
        if int(self.a)>=1582:
            if (int(self.a)%4==0 and not int(self.a)%100==0) or int(self.a)%400==0:
                return f"{self.a} est une année bisextile "
            else :
                    return f"{self.a} n'est pas une année bisextile "
        else:
            return f"Votre année est inférieur a 1582"
        
    def age(self, j, m, a):
        if (self.m>Mois_actuel) or (self.m==Mois_actuel and self.j>Jour_actuel):
            Age= An_actuel-self.a-1
        else :
            Age = An_actuel-self.a
        return f"Tu as {Age} ans."
        
    
    def infos(self, j, m, a):
        if m>12:
            return f"Cette date n'existe pas"
        if m == 1:
            m = 'Janvier'
        if m == 2:
            m = 'Février'
        if m == 3:
            m = 'Mars'
        if m == 4:
            m = 'Avril'
        if m == 5:
            m = 'Mai'
        if m == 6:
            m = 'Juin'
        if m == 7:
            m = 'Juillet'
        if m == 8:
            m = 'Août'
        if m == 9:
            m = 'Septembre'
        if m == 10:
            m = 'Octobre'
        if m == 11:
            m = 'Novembre'
        if m == 12:
            m = 'Décembre'
        return (f"Informations sur votre année de naissance : https://fr.wikipedia.org/wiki/{a}"
        f"ㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤ Informations sur votre mois de naissance https://fr.wikipedia.org/wiki/{m}_{a} ")

    def __repr__(self):
        return str(self.a)
    
    def __str__(self):
        return str(self.a)

# %%
d = naissance(9,11,2004)
d.bissextile(j, m, a)
# Out:
# '2004 est une année bisextile '
